# %% [markdown]
# LAB:3
# "Processing Tiff Images For Machine Learning Techniques"

# %%
# !pip install geos
# Out:
# Collecting geos
#   Downloading geos-0.2.3-py3-none-any.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.3/400.3 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from geos) (2.2.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from geos) (4.9.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from geos) (9.4.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask->geos) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask->geos) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask->geos) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask->geos) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask->geos) (2.1.3)
# Installing collected packages: geos
# Successfully installed geos-0.2.3

# %%
from rasterio.plot import show
import geos
import rasterio
import geotiff
import tifffile
import matplotlib.pyplot as plt #For plotting our visualizations
from keras.preprocessing.image import ImageDataGenerator #Keras dataset generator class.
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import cv2
from PIL import Image

# %matplotlib inline  # Uncomment this line if running this code in Jypiter notebook

image = rasterio.open("/content/drive/MyDrive/DIP_CITY_DATA /HH-ALPSRP247640490-H2.2_UA.tif")
show(image)
# Out:
# WARNING:rasterio._env:CPLE_AppDefined in The definition of projected CRS EPSG:32642 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.
# <Axes: >

# %%
# !pip install Keras!pip install
# !pip install opencv-python
# Out:
# ERROR: Invalid requirement: 'Keras!pip'
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)

# %% [markdown]
# "Horizontal Shift"

# %%
# from rasterio.plot import show
# import geos
# import rasterio
# import geotiff
# import tifffile
# from numpy import expand_dims
# from keras.preprocessing.image import load_img
# from keras.preprocessing.image import img_to_array
# import cv2
# from PIL import Image

# image = rasterio.open("C:\\Users\\Ahtasham Ahmed\\OneDrive - Higher Education Commission\\Desktop\\Python\\Microwave lab\\Data\\ALPSRP244140480-H2.2_UA\\HH-ALPSRP244140480-H2.2_UA.tif")

# data = img_to_array(image)
# samples = expand_dims(data, 0)
# data_generator = ImageDataGenerator(height_shift_range=0.5)
# it = data_generator.flow(samples, batch_size=1)
# for i in range(9):
#     plt.subplot(330 + 1 + i)
#     batch = it.next()
#     result = batch[0].astype('uint16')
#     plt.imshow(result)
# plt.show()

from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator

# Open the raster file using rasterio
image_path = "/content/drive/MyDrive/DIP_CITY_DATA /HH-ALPSRP247640490-H2.2_UA.tif"
image = rasterio.open(image_path)

# Read the image data and convert it to a NumPy array
data = image.read()
data = data.transpose(1, 2, 0)  # Transpose to (height, width, channels)

# Data augmentation
samples = expand_dims(data, 0)
data_generator = ImageDataGenerator(height_shift_range=0.5)
it = data_generator.flow(samples, batch_size=1)

# Display augmented images
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()
# Out:
# WARNING:rasterio._env:CPLE_AppDefined in The definition of projected CRS EPSG:32642 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.

# %% [markdown]
# "Vertical Shift"

# %%
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator

# Open the raster file using rasterio
image_path = "/content/drive/MyDrive/DIP_CITY_DATA /HH-ALPSRP247640490-H2.2_UA.tif"
image = rasterio.open(image_path)

# Read the image data and convert it to a NumPy array
data = image.read()
data = data.transpose(1, 2, 0)  # Transpose to (height, width, channels)

# Data augmentation
samples = expand_dims(data, 0)
data_generator = ImageDataGenerator(width_shift_range=0.5)
it = data_generator.flow(samples, batch_size=1)

# Display augmented images
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()
# Out:
# WARNING:rasterio._env:CPLE_AppDefined in The definition of projected CRS EPSG:32642 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.

# %% [markdown]
# "Enhancing Color/Color Space"

# %%
# from rasterio.plot import show
# import rasterio
# from numpy import expand_dims
# from keras.preprocessing.image import ImageDataGenerator

# # Open the raster file using rasterio
# image_path = "C:\\Users\\Ahtasham Ahmed\\OneDrive - Higher Education Commission\\Desktop\\Python\\Microwave lab\\Data\\ALPSRP244140480-H2.2_UA\\HH-ALPSRP244140480-H2.2_UA.tif"
# image = rasterio.open(image_path)

# # Read the image data and convert it to a NumPy array
# data = image.read()
# data = data.transpose(1, 2, 0)  # Transpose to (height, width, channels)

# # Data augmentation
# data = img_to_array(image)
# samples = expand_dims(data, 0)
# datagen = ImageDataGenerator(brightness_range=[0.2,1.0])
# it = datagen.flow(samples, batch_size=1)

# # Display augmented images
# import matplotlib.pyplot as plt

# plt.figure(figsize=(10, 10))
# for i in range(9):
#     plt.subplot(330 + 1 + i)
#     batch = it.next()
#     result = batch[0].astype('uint16')
#     plt.imshow(result)

# plt.show()
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator, img_to_array
import matplotlib.pyplot as plt

# Open the raster file using rasterio
image_path = "/content/drive/MyDrive/DIP_CITY_DATA /HH-ALPSRP247640490-H2.2_UA.tif"
image = rasterio.open(image_path)

# Read the image data and convert it to a NumPy array
data = image.read()
data = data.transpose(1, 2, 0)  # Transpose to (height, width, channels)

# Data augmentation
samples = expand_dims(data, 0)
datagen = ImageDataGenerator(brightness_range=[0.5, 1])
it = datagen.flow(samples, batch_size=1)

# Display augmented images
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()
# Out:
# WARNING:rasterio._env:CPLE_AppDefined in The definition of projected CRS EPSG:32642 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.

# %% [markdown]
# "Zoom In"

# %%
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator, img_to_array
import matplotlib.pyplot as plt

# Open the raster file using rasterio
image_path = "/content/drive/MyDrive/DIP_CITY_DATA /HH-ALPSRP247640490-H2.2_UA.tif"
image = rasterio.open(image_path)

# Read the image data and convert it to a NumPy array
data = image.read()
data = data.transpose(1, 2, 0)  # Transpose to (height, width, channels)

# Data augmentation
samples = expand_dims(data, 0)
datagen = ImageDataGenerator(zoom_range=[1,10])
it = datagen.flow(samples, batch_size=1)

# Display augmented images
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()
# Out:
# WARNING:rasterio._env:CPLE_AppDefined in The definition of projected CRS EPSG:32642 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.

# %% [markdown]
# "Flipping"

# %%
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator, img_to_array
import matplotlib.pyplot as plt

# Open the raster file using rasterio
image_path = "/content/drive/MyDrive/DIP_CITY_DATA /HH-ALPSRP247640490-H2.2_UA.tif"
image = rasterio.open(image_path)

# Read the image data and convert it to a NumPy array
data = image.read()
data = data.transpose(1, 2, 0)  # Transpose to (height, width, channels)

# Data augmentation
samples = expand_dims(data, 0)
datagen = ImageDataGenerator(vertical_flip=True)
it = datagen.flow(samples, batch_size=1)

# Display augmented images
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()
# Out:
# WARNING:rasterio._env:CPLE_AppDefined in The definition of projected CRS EPSG:32642 got from GeoTIFF keys is not the same as the one from the EPSG registry, which may cause issues during reprojection operations. Set GTIFF_SRS_SOURCE configuration option to EPSG to use official parameters (overriding the ones from GeoTIFF keys), or to GEOKEYS to use custom values from GeoTIFF keys and drop the EPSG code.
